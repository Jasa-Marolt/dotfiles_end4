# %%
# This is a code cell
import numpy as np
import matplotlib.pyplot as plt

print("Hello from Molten!")

# %%
# Another code cell
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %%
# Math and variables
result = 2 + 2
result
